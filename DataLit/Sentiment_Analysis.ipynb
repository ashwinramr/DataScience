# %%
# !pip install pandas
# !pip install tweepy
# !pip install vaderSentiment
# Out:
# ...
#     100% |████████████████████████████████| 133kB 4.8MB/s
# ...

# %%
import tweepy
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
#My Twitter API Authentication Variables
consumer_key = 'pkaAreRxG8TqAZGv12Jf98Mok'
consumer_secret = 'uRqYixrVB0JpVMTYr2EH1kpyikIBFyMg4rg60nsEyD4nuIdwOd'
access_token = '57309077-k4IzY4D2p6VcASOS9YSPVrmpdUeOqCwd4gG3Y1pL7'
access_token_secret = 'l0TK2mDQuofbHRrnna23ht4DJvzHxnDAQo4Ui34bMr3MK'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

tweets = api.search('Trump', count=200)


data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

display(data.head(10))


print(tweets[0].created_at)
# Out:
#                                               Tweets
# 0  RT @jimsciutto: The news from Trump's tweets t...
# 1  Yet more trouble in Trump World with new tell-...
# 2  RT @benwikler: America, remember. It wasn't ju...
# 3  RT @EdKrassen: Next Week on @KrassenCast, we w...
# 4  RT @chelseahandler: Trump is expected to spend...
# 5  RT @TrumpsDC: Juan Williams just said on The F...
# 6  RT @GOPChairwoman: Nearly 2/3 of voters in DEM...
# 7  RT @selectedwisdom: US Intel chiefs offered re...
# 8  RT @robreiner: The horrific attack on Jussie S...
# 9  RT @thehill: JUST IN: Trump breaks with his in...
# 2019-01-30 12:31:54

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/ashwin/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
sid = SentimentIntensityAnalyzer()


listy = []

for index, row in data.iterrows():
  ss = sid.polarity_scores(row["Tweets"])
  listy.append(ss)
  
se = pd.Series(listy)
data['polarity'] = se.values

display(data.head(100))
# Out:
#                                                Tweets  \
# 0   RT @jimsciutto: The news from Trump's tweets t...
# 1   Yet more trouble in Trump World with new tell-...
# 2   RT @benwikler: America, remember. It wasn't ju...
# 3   RT @EdKrassen: Next Week on @KrassenCast, we w...
# 4   RT @chelseahandler: Trump is expected to spend...
# 5   RT @TrumpsDC: Juan Williams just said on The F...
# 6   RT @GOPChairwoman: Nearly 2/3 of voters in DEM...
# 7   RT @selectedwisdom: US Intel chiefs offered re...
# 8   RT @robreiner: The horrific attack on Jussie S...
# 9   RT @thehill: JUST IN: Trump breaks with his in...
# 10  EU's Iran fight is not about Iran (or Trump) h...
# 11  RT @kenyadad12: To all the Trump conspirators ...
# 12  RT @CyrusMMcQueen: Roger Stone said “This is a...
# 13  @Lady_Vi_2U @MatthewCharti11 But we need to st...
# 14  RT @fred_guttenberg: @WhiteHouse Wonder if you...
# 15  RT @EdKrassen: Melania Trump said she's workin...
# ...
